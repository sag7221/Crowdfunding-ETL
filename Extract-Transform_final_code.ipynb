# %%
import pandas as pd
import json

# %% [markdown]
# ## Deliverable 1: Extract
# ----
# ### Option 1: Use Python Dictionary Methods
#
# 1. Import the `backer_info.csv` file into a DataFrame.
# 2. Iterate through the DataFrame and convert each row to a dictionary.
# 3. Iterate through each dictionary and do the following:
#     * Extract the dictionary values from the keys using Python list comprehension.
#     * Add the values for each row to a new list.
# 4. Create a new DataFrame with the retrieved data.
# 5. Export the DataFrame as `backers_data.csv`.

# %%
# Get the backers_info.csv 
pd.set_option('max_colwidth', 400)
backer_info_df = pd.read_csv('backer_info.csv')
backer_info_df.head()
# Out:
#                                                                                           backer_info
# 0        {"backer_id": "av166", "cf_id": 968, "name": "Angelo Vincent", "email": "avincent@live.com"}
# 1        {"backer_id": "ha127", "cf_id": 563, "name": "Hubert Arnold", "email": "harnold@yandex.com"}
# 2          {"backer_id": "lg794", "cf_id": 65, "name": "Loris Goulet", "email": "lgoulet@yandex.com"}
# 3  {"backer_id": "tb566", "cf_id": 563, "name": "Teodora Brunelli", "email": "tbrunelli@outlook.com"}
# 4               {"backer_id": "lh506", "cf_id": 563, "name": "Lexie Hunt", "email": "lhunt@live.com"}

# %%
# Iterate through the backers DataFrame and convert each row to a dictionary.
backer_dict_values = []
    # Iterate through each dictionary (row) and get the values for each row using list comprehension.
for i, row in backer_info_df.iterrows():
    data = row['backer_info']
    converted_data = json.loads(data)
    print(converted_data.items())
    # Append the list of values for each row to a list. 
    row_values = [v for k,v in converted_data.items()]
    backer_dict_values.append(row_values)

# Print out the list of values for each row.
print(backer_dict_values)
# Out:
# dict_items([('backer_id', 'av166'), ('cf_id', 968), ('name', 'Angelo Vincent'), ('email', 'avincent@live.com')])
# dict_items([('backer_id', 'ha127'), ('cf_id', 563), ('name', 'Hubert Arnold'), ('email', 'harnold@yandex.com')])
# dict_items([('backer_id', 'lg794'), ('cf_id', 65), ('name', 'Loris Goulet'), ('email', 'lgoulet@yandex.com')])
# dict_items([('backer_id', 'tb566'), ('cf_id', 563), ('name', 'Teodora Brunelli'), ('email', 'tbrunelli@outlook.com')])
# dict_items([('backer_id', 'lh506'), ('cf_id', 563), ('name', 'Lexie Hunt'), ('email', 'lhunt@live.com')])
# dict_items([('backer_id', 'lh382'), ('cf_id', 563), ('name', 'Lambert Huber'), ('email', 'lhuber@live.com')])
# dict_items([('backer_id', 'em444'), ('cf_id', 563), ('name', 'Emmy Morin'), ('email', 'emorin@live.com')])
# dict_items([('backer_id', 'at582'), ('cf_id', 1572), ('name', 'Armonda Trani'), ('email', 'atrani@live.com')])
# dict_items([('backer_id', 'id772'), ('cf_id', 1911), ('name', 'Ilana Duke'), ('email', 'iduke@outlook.com')])
# dict_items([('backer_id', 'lw275'), ('cf_id', 65), ('name', 'Leigha Wright'), ('email', 'lwright@live.com')])
# dict_items([('backer_id', 'ub509'), ('cf_id', 65), ('name', 'Uwe Becker'), ('email', 'ubecker@yahoo.com')])
# dict_items([('backer_id', 'ha915'), ('cf_id', 1572), ('name', 'Hawa Audy'), ('email', 'haudy@gmail.com')])
# dict_items([('backer_id', 'bb881'), ('cf_id', 968), ('name', 'Bia Bonura'), ('email', 'bbonura@yahoo.com')])
# dict_items([('backer_id', 'mg332'), ('cf_id', 65), ('name', 'Michel Garner'), ('email', 'mgarner@protonmail.com')])
# dict_items([('backer_id', 'kd700'), ('cf_id', 1572), ('name', 'Karole Dunn'), ('email', 'kdunn@yahoo.com')])
# dict_items([('backer_id', 'as695'), ('cf_id', 563), ('name', 'Arndt Schreiber'), ('email', 'aschreiber@yahoo.com')])
# dict_items([('backer_id', 'iv513'), ('cf_id', 65), ('name', 'Imen Villeneuve'), ('email', 'ivilleneuve@yahoo.com')])
# dict_items([('backer_id', 'ab842'), ('cf_id', 65), ('name', 'Alcina Bonadonna'), ('email', 'abonadonna@yandex.com')])
# dict_items([('backer_id', 're181'), ('cf_id', 1114), ('name', 'Raelene Espinoza'), ('email', 'respinoza@outlook.com')])
# dict_items([('backer_id', 'kn133'), ('cf_id', 65), ('name', 'Kati Nash'), ('email', 'knash@protonmail.com')])
# dict_items([('backer_id', 'gj893'), ('cf_id', 65), ('name', 'Georg Jager'), ('email', 'gjager@yahoo.com')])
# dict_items([('backer_id', 'vp915'), ('cf_id', 948), ('name', 'Virgilio Paolella'), ('email', 'vpaolella@gmail.com')])
# dict_items([('backer_id', 'ja995'), ('cf_id', 563), ('name', 'Jerrica Avila'), ('email', 'javila@protonmail.com')])
# dict_items([('backer_id', 'ga249'), ('cf_id', 563), ('name', 'Gianni Achterberg'), ('email', 'gachterberg@live.com')])
# dict_items([('backer_id', 'td403'), ('cf_id', 65), ('name', 'Timoteo Dion'), ('email', 'tdion@gmail.com')])
# dict_items([('backer_id', 'tv463'), ('cf_id', 1572), ('name', 'Teodoro Verno'), ('email', 'tverno@yandex.com')])
# dict_items([('backer_id', 'mw606'), ('cf_id', 65), ('name', 'Morris Waller'), ('email', 'mwaller@protonmail.com')])
# dict_items([('backer_id', 'hc648'), ('cf_id', 65), ('name', 'Hans Chen'), ('email', 'hchen@yandex.com')])
# dict_items([('backer_id', 'ta379'), ('cf_id', 563), ('name', 'Trilby Auer'), ('email', 'tauer@yahoo.com')])
# dict_items([('backer_id', 'tj583'), ('cf_id', 1572), ('name', 'Theola Jodoin'), ('email', 'tjodoin@yandex.com')])
# dict_items([('backer_id', 'tc559'), ('cf_id', 65), ('name', 'Tova Capri'), ('email', 'tcapri@live.com')])
# dict_items([('backer_id', 'ww629'), ('cf_id', 65), ('name', 'Wanda Walton'), ('email', 'wwalton@protonmail.com')])
# dict_items([('backer_id', 'jg155'), ('cf_id', 1572), ('name', 'Justine Gill'), ('email', 'jgill@yahoo.com')])
# dict_items([('backer_id', 'jd328'), ('cf_id', 1911), ('name', 'Julee Doyle'), ('email', 'jdoyle@gmail.com')])
# dict_items([('backer_id', 'ld239'), ('cf_id', 65), ('name', 'Lisbeth Deliso'), ('email', 'ldeliso@gmail.com')])
# dict_items([('backer_id', 'cv918'), ('cf_id', 968), ('name', 'Carl Valdez'), ('email', 'cvaldez@gmail.com')])
# dict_items([('backer_id', 'kb145'), ('cf_id', 563), ('name', 'Kelyan Butler'), ('email', 'kbutler@yahoo.com')])
# dict_items([('backer_id', 'dw578'), ('cf_id', 65), ('name', 'Donat Weber'), ('email', 'dweber@live.com')])
# dict_items([('backer_id', 'ad511'), ('cf_id', 65), ('name', 'Alethia Delorme'), ('email', 'adelorme@outlook.com')])
# dict_items([('backer_id', 'db633'), ('cf_id', 65), ('name', 'Darrell Bernardi'), ('email', 'dbernardi@yandex.com')])
# dict_items([('backer_id', 'cr369'), ('cf_id', 65), ('name', 'Carina Reeves'), ('email', 'creeves@gmail.com')])
# dict_items([('backer_id', 'mr978'), ('cf_id', 65), ('name', 'Marvin Ruiz'), ('email', 'mruiz@outlook.com')])
# dict_items([('backer_id', 'md167'), ('cf_id', 1572), ('name', 'Mariabella Duerr'), ('email', 'mduerr@live.com')])
# dict_items([('backer_id', 'jr877'), ('cf_id', 1572), ('name', 'Jeni Ricco'), ('email', 'jricco@live.com')])
# dict_items([('backer_id', 'om753'), ('cf_id', 65), ('name', 'Otto Munoz'), ('email', 'omunoz@yahoo.com')])
# dict_items([('backer_id', 'ng231'), ('cf_id', 1114), ('name', 'Nesrine Gensch'), ('email', 'ngensch@yandex.com')])
# dict_items([('backer_id', 'tl316'), ('cf_id', 65), ('name', 'Tullio Lejeune'), ('email', 'tlejeune@outlook.com')])
# dict_items([('backer_id', 'dl139'), ('cf_id', 563), ('name', 'Dreama Lonardo'), ('email', 'dlonardo@live.com')])
# dict_items([('backer_id', 'mw253'), ('cf_id', 968), ('name', 'Maryrose West'), ('email', 'mwest@live.com')])
# dict_items([('backer_id', 'im424'), ('cf_id', 65), ('name', 'Irina Mays'), ('email', 'imays@yandex.com')])
# dict_items([('backer_id', 'mb131'), ('cf_id', 968), ('name', 'Marcelo Brose'), ('email', 'mbrose@protonmail.com')])
# dict_items([('backer_id', 'nc240'), ('cf_id', 1572), ('name', 'Nestor Coutant'), ('email', 'ncoutant@gmail.com')])
# dict_items([('backer_id', 'ab318'), ('cf_id', 1572), ('name', 'Aloysius Braun'), ('email', 'abraun@live.com')])
# dict_items([('backer_id', 'af301'), ('cf_id', 65), ('name', 'Amos Ferre'), ('email', 'aferre@gmail.com')])
# dict_items([('backer_id', 'bl736'), ('cf_id', 563), ('name', 'Brigitte Lynch'), ('email', 'blynch@outlook.com')])
# dict_items([('backer_id', 'ar957'), ('cf_id', 65), ('name', 'Alegra Ramsey'), ('email', 'aramsey@yahoo.com')])
# dict_items([('backer_id', 'cb474'), ('cf_id', 968), ('name', 'Conchita Beitel'), ('email', 'cbeitel@gmail.com')])
# dict_items([('backer_id', 'dv246'), ('cf_id', 1572), ('name', 'Donnie Vernet'), ('email', 'dvernet@protonmail.com')])
# dict_items([('backer_id', 'cj111'), ('cf_id', 563), ('name', 'Cyril Jones'), ('email', 'cjones@protonmail.com')])
# dict_items([('backer_id', 'lh765'), ('cf_id', 563), ('name', 'Lucinda Hays'), ('email', 'lhays@outlook.com')])
# dict_items([('backer_id', 'wh697'), ('cf_id', 65), ('name', 'Walter Hermann'), ('email', 'whermann@outlook.com')])
# dict_items([('backer_id', 'eb714'), ('cf_id', 65), ('name', 'Emil Blanc'), ('email', 'eblanc@protonmail.com')])
# dict_items([('backer_id', 'ec356'), ('cf_id', 1572), ('name', 'Eldwin Cesare'), ('email', 'ecesare@protonmail.com')])
# dict_items([('backer_id', 'yh129'), ('cf_id', 65), ('name', 'Yusuf Hudson'), ('email', 'yhudson@protonmail.com')])
# dict_items([('backer_id', 'as494'), ('cf_id', 65), ('name', 'Arrigo Salazar'), ('email', 'asalazar@gmail.com')])
# dict_items([('backer_id', 'lb146'), ('cf_id', 563), ('name', 'Levi Beck'), ('email', 'lbeck@gmail.com')])
# dict_items([('backer_id', 'cc470'), ('cf_id', 563), ('name', 'Celinda Caillet'), ('email', 'ccaillet@yandex.com')])
# dict_items([('backer_id', 'mm239'), ('cf_id', 563), ('name', 'Marcus Medici'), ('email', 'mmedici@gmail.com')])
# dict_items([('backer_id', 'dg360'), ('cf_id', 65), ('name', 'Daysi Gamble'), ('email', 'dgamble@yahoo.com')])
# dict_items([('backer_id', 'rh399'), ('cf_id', 1572), ('name', 'Rory Hildebrand'), ('email', 'rhildebrand@yahoo.com')])
# dict_items([('backer_id', 'hr430'), ('cf_id', 65), ('name', 'Heini Raffin'), ('email', 'hraffin@yahoo.com')])
# dict_items([('backer_id', 'ar829'), ('cf_id', 65), ('name', 'Anna Randall'), ('email', 'arandall@outlook.com')])
# dict_items([('backer_id', 'sw301'), ('cf_id', 65), ('name', 'Sharmaine Weber'), ('email', 'sweber@yahoo.com')])
# dict_items([('backer_id', 'rr355'), ('cf_id', 65), ('name', 'Ranee Renault'), ('email', 'rrenault@outlook.com')])
# dict_items([('backer_id', 'zc515'), ('cf_id', 1572), ('name', 'Zak Cianciola'), ('email', 'zcianciola@yahoo.com')])
# dict_items([('backer_id', 'gp101'), ('cf_id', 65), ('name', 'Granville Potts'), ('email', 'gpotts@gmail.com')])
# dict_items([('backer_id', 'bm741'), ('cf_id', 65), ('name', 'Bo Marsh'), ('email', 'bmarsh@live.com')])
# dict_items([('backer_id', 'jd148'), ('cf_id', 65), ('name', 'Jay Duerr'), ('email', 'jduerr@yahoo.com')])
# dict_items([('backer_id', 'mm632'), ('cf_id', 65), ('name', 'Milla Morin'), ('email', 'mmorin@yahoo.com')])
# dict_items([('backer_id', 'ls884'), ('cf_id', 65), ('name', 'Leanne Savage'), ('email', 'lsavage@gmail.com')])
# dict_items([('backer_id', 'sp364'), ('cf_id', 968), ('name', 'Silvana Patton'), ('email', 'spatton@live.com')])
# dict_items([('backer_id', 'hh963'), ('cf_id', 65), ('name', 'Harvey Hoch'), ('email', 'hhoch@outlook.com')])
# dict_items([('backer_id', 'sb272'), ('cf_id', 65), ('name', 'Seth Berthier'), ('email', 'sberthier@protonmail.com')])
# dict_items([('backer_id', 'et566'), ('cf_id', 1114), ('name', 'Eugen Trani'), ('email', 'etrani@protonmail.com')])
# dict_items([('backer_id', 'sd421'), ('cf_id', 1572), ('name', 'Santina Dieter'), ('email', 'sdieter@yahoo.com')])
# dict_items([('backer_id', 'tg563'), ('cf_id', 65), ('name', 'Trinh Gregoire'), ('email', 'tgregoire@live.com')])
# dict_items([('backer_id', 'kc571'), ('cf_id', 968), ('name', 'Karin Celano'), ('email', 'kcelano@yandex.com')])
# dict_items([('backer_id', 'sd121'), ('cf_id', 1114), ('name', 'Sofia Decker'), ('email', 'sdecker@yahoo.com')])
# dict_items([('backer_id', 'sk744'), ('cf_id', 65), ('name', 'Sherise Keller'), ('email', 'skeller@outlook.com')])
# dict_items([('backer_id', 'km642'), ('cf_id', 65), ('name', 'Kirby Michel'), ('email', 'kmichel@gmail.com')])
# dict_items([('backer_id', 'fu320'), ('cf_id', 65), ('name', 'Florentine Ungaro'), ('email', 'fungaro@yandex.com')])
# dict_items([('backer_id', 'ld180'), ('cf_id', 1911), ('name', 'Louise Dejesus'), ('email', 'ldejesus@yandex.com')])
# dict_items([('backer_id', 'ds377'), ('cf_id', 65), ('name', 'Daniele Suarez'), ('email', 'dsuarez@yahoo.com')])
# dict_items([('backer_id', 'bb692'), ('cf_id', 65), ('name', 'Beckie Buchholz'), ('email', 'bbuchholz@live.com')])
# dict_items([('backer_id', 'wd557'), ('cf_id', 563), ('name', 'William Dickson'), ('email', 'wdickson@yandex.com')])
# dict_items([('backer_id', 'jd905'), ('cf_id', 65), ('name', 'Jolie Daugherty'), ('email', 'jdaugherty@gmail.com')])
# dict_items([('backer_id', 'dd770'), ('cf_id', 65), ('name', 'Detta Dressler'), ('email', 'ddressler@yahoo.com')])
# dict_items([('backer_id', 'cv698'), ('cf_id', 238), ('name', 'Clifton Villette'), ('email', 'cvillette@outlook.com')])
# dict_items([('backer_id', 'cn307'), ('cf_id', 968), ('name', 'Cythia Netti'), ('email', 'cnetti@outlook.com')])
# dict_items([('backer_id', 'eb198'), ('cf_id', 1572), ('name', 'Elsbeth Butler'), ('email', 'ebutler@yahoo.com')])
# dict_items([('backer_id', 'am869'), ('cf_id', 65), ('name', 'Ambrine Mann'), ('email', 'amann@yahoo.com')])
# dict_items([('backer_id', 'gr400'), ('cf_id', 1911), ('name', 'Gerald Robert'), ('email', 'grobert@protonmail.com')])
# dict_items([('backer_id', 'az657'), ('cf_id', 563), ('name', 'Assunta Zezza'), ('email', 'azezza@live.com')])
# dict_items([('backer_id', 'kc598'), ('cf_id', 1572), ('name', 'Kerstin Campbell'), ('email', 'kcampbell@protonmail.com')])
# dict_items([('backer_id', 'lb588'), ('cf_id', 65), ('name', 'Lino Brock'), ('email', 'lbrock@outlook.com')])
# dict_items([('backer_id', 'rl866'), ('cf_id', 65), ('name', 'Rubie Levasseur'), ('email', 'rlevasseur@gmail.com')])
# dict_items([('backer_id', 'jf340'), ('cf_id', 65), ('name', 'Johann Flowers'), ('email', 'jflowers@live.com')])
# dict_items([('backer_id', 'tb384'), ('cf_id', 1572), ('name', 'Thibaud Bullock'), ('email', 'tbullock@yahoo.com')])
# dict_items([('backer_id', 'dg290'), ('cf_id', 65), ('name', 'Dan Gallois'), ('email', 'dgallois@outlook.com')])
# dict_items([('backer_id', 'rr518'), ('cf_id', 65), ('name', 'Rolf Richards'), ('email', 'rrichards@live.com')])
# dict_items([('backer_id', 'sh779'), ('cf_id', 968), ('name', 'Selyan Hoffman'), ('email', 'shoffman@outlook.com')])
# dict_items([('backer_id', 'lw525'), ('cf_id', 65), ('name', 'Lucca Weber'), ('email', 'lweber@live.com')])
# dict_items([('backer_id', 'sl474'), ('cf_id', 563), ('name', 'Sydney Louvet'), ('email', 'slouvet@gmail.com')])
# dict_items([('backer_id', 'dp154'), ('cf_id', 65), ('name', 'Dusty Paola'), ('email', 'dpaola@outlook.com')])
# dict_items([('backer_id', 'id770'), ('cf_id', 238), ('name', 'Ilario Dressler'), ('email', 'idressler@protonmail.com')])
# dict_items([('backer_id', 'ek669'), ('cf_id', 65), ('name', 'Emile Khan'), ('email', 'ekhan@outlook.com')])
# dict_items([('backer_id', 'eb945'), ('cf_id', 65), ('name', 'Elliot Bonomo'), ('email', 'ebonomo@yandex.com')])
# dict_items([('backer_id', 'ag917'), ('cf_id', 1114), ('name', 'Arvin Golden'), ('email', 'agolden@yandex.com')])
# dict_items([('backer_id', 'ac437'), ('cf_id', 563), ('name', 'Ampelio Cabrera'), ('email', 'acabrera@live.com')])
# dict_items([('backer_id', 'sf583'), ('cf_id', 1572), ('name', 'Somer Fuhrmann'), ('email', 'sfuhrmann@yahoo.com')])
# dict_items([('backer_id', 'sa973'), ('cf_id', 65), ('name', 'Shanti Allard'), ('email', 'sallard@yandex.com')])
# dict_items([('backer_id', 'kc836'), ('cf_id', 65), ('name', 'Konstanze Caroselli'), ('email', 'kcaroselli@yandex.com')])
# dict_items([('backer_id', 'bt844'), ('cf_id', 65), ('name', 'Bellarmine Taylor'), ('email', 'btaylor@outlook.com')])
# dict_items([('backer_id', 'mf392'), ('cf_id', 65), ('name', 'Matthew Fischer'), ('email', 'mfischer@live.com')])
# dict_items([('backer_id', 'dh568'), ('cf_id', 65), ('name', 'Dan Hoffmann'), ('email', 'dhoffmann@yandex.com')])
# dict_items([('backer_id', 'iv880'), ('cf_id', 968), ('name', 'Imelda Vallee'), ('email', 'ivallee@gmail.com')])
# dict_items([('backer_id', 'gl219'), ('cf_id', 1572), ('name', 'Giancarlo Lindsey'), ('email', 'glindsey@protonmail.com')])
# dict_items([('backer_id', 'kb890'), ('cf_id', 1572), ('name', 'Kris Brennan'), ('email', 'kbrennan@protonmail.com')])
# dict_items([('backer_id', 'jf901'), ('cf_id', 65), ('name', 'Johnnie Fux'), ('email', 'jfux@gmail.com')])
# dict_items([('backer_id', 'ja340'), ('cf_id', 1114), ('name', 'Janeth Adam'), ('email', 'jadam@protonmail.com')])
# dict_items([('backer_id', 'ar906'), ('cf_id', 65), ('name', 'Agata Rosa'), ('email', 'arosa@yahoo.com')])
# dict_items([('backer_id', 'dc579'), ('cf_id', 65), ('name', 'Dennise Cabrera'), ('email', 'dcabrera@live.com')])
# dict_items([('backer_id', 'gg660'), ('cf_id', 65), ('name', 'Garret Geier'), ('email', 'ggeier@yahoo.com')])
# dict_items([('backer_id', 'db112'), ('cf_id', 65), ('name', 'Delia Beguin'), ('email', 'dbeguin@yandex.com')])
# dict_items([('backer_id', 'ld487'), ('cf_id', 65), ('name', 'Louanne Damiani'), ('email', 'ldamiani@outlook.com')])
# dict_items([('backer_id', 'bj475'), ('cf_id', 1572), ('name', 'Bronze Jenkins'), ('email', 'bjenkins@protonmail.com')])
# dict_items([('backer_id', 'mc838'), ('cf_id', 65), ('name', 'Mila Coffey'), ('email', 'mcoffey@protonmail.com')])
# dict_items([('backer_id', 'he768'), ('cf_id', 65), ('name', 'Hank Essert'), ('email', 'hessert@gmail.com')])
# dict_items([('backer_id', 'pm973'), ('cf_id', 65), ('name', 'Paulina Marais'), ('email', 'pmarais@protonmail.com')])
# dict_items([('backer_id', 'bf986'), ('cf_id', 65), ('name', 'Beatrice Fulco'), ('email', 'bfulco@gmail.com')])
# dict_items([('backer_id', 'sb322'), ('cf_id', 65), ('name', 'Sudie Burgess'), ('email', 'sburgess@yandex.com')])
# dict_items([('backer_id', 'ps571'), ('cf_id', 563), ('name', 'Prince Suarez'), ('email', 'psuarez@yahoo.com')])
# dict_items([('backer_id', 'mb333'), ('cf_id', 1572), ('name', 'Mitzi Biermann'), ('email', 'mbiermann@gmail.com')])
# dict_items([('backer_id', 'ab290'), ('cf_id', 1572), ('name', 'Aminata Bru'), ('email', 'abru@yahoo.com')])
# dict_items([('backer_id', 'jm190'), ('cf_id', 968), ('name', 'Jina Magrino'), ('email', 'jmagrino@live.com')])
# dict_items([('backer_id', 'rg933'), ('cf_id', 65), ('name', 'Rosena Gould'), ('email', 'rgould@gmail.com')])
# dict_items([('backer_id', 'ik787'), ('cf_id', 1572), ('name', 'Issac Kline'), ('email', 'ikline@live.com')])
# dict_items([('backer_id', 'rl982'), ('cf_id', 65), ('name', 'Roderica Lehmann'), ('email', 'rlehmann@gmail.com')])
# dict_items([('backer_id', 'ac179'), ('cf_id', 65), ('name', 'Ariah Comte'), ('email', 'acomte@yandex.com')])
# dict_items([('backer_id', 'eg193'), ('cf_id', 238), ('name', 'Ellis Gamble'), ('email', 'egamble@yahoo.com')])
# dict_items([('backer_id', 'fl258'), ('cf_id', 65), ('name', 'Friedrich Lott'), ('email', 'flott@yandex.com')])
# dict_items([('backer_id', 'mb203'), ('cf_id', 1114), ('name', 'Marilou Beutel'), ('email', 'mbeutel@gmail.com')])
# dict_items([('backer_id', 'en399'), ('cf_id', 65), ('name', 'Elene Navarro'), ('email', 'enavarro@yahoo.com')])
# dict_items([('backer_id', 'mr756'), ('cf_id', 968), ('name', 'Mac Raffin'), ('email', 'mraffin@yahoo.com')])
# dict_items([('backer_id', 'sc271'), ('cf_id', 563), ('name', 'Shona Carr'), ('email', 'scarr@outlook.com')])
# dict_items([('backer_id', 'xg684'), ('cf_id', 1572), ('name', 'Ximena Guy'), ('email', 'xguy@protonmail.com')])
# dict_items([('backer_id', 'ab829'), ('cf_id', 563), ('name', 'Arnaud Becker'), ('email', 'abecker@live.com')])
# dict_items([('backer_id', 'fd404'), ('cf_id', 65), ('name', 'Fiore Desautels'), ('email', 'fdesautels@live.com')])
# dict_items([('backer_id', 'rm849'), ('cf_id', 563), ('name', 'Robby Mccray'), ('email', 'rmccray@gmail.com')])
# dict_items([('backer_id', 'lr658'), ('cf_id', 65), ('name', 'Louis Rush'), ('email', 'lrush@protonmail.com')])
# dict_items([('backer_id', 'sh994'), ('cf_id', 65), ('name', 'Serena Holzknecht'), ('email', 'sholzknecht@protonmail.com')])
# dict_items([('backer_id', 'zv654'), ('cf_id', 65), ('name', 'Zan Verdier'), ('email', 'zverdier@yahoo.com')])
# dict_items([('backer_id', 'hb861'), ('cf_id', 1572), ('name', 'Hipolito Baldocchi'), ('email', 'hbaldocchi@gmail.com')])
# dict_items([('backer_id', 'hb280'), ('cf_id', 65), ('name', 'Hollis Barnett'), ('email', 'hbarnett@live.com')])
# dict_items([('backer_id', 'be560'), ('cf_id', 65), ('name', 'Barend Edwards'), ('email', 'bedwards@yandex.com')])
# dict_items([('backer_id', 'lh820'), ('cf_id', 563), ('name', 'Loane Holst'), ('email', 'lholst@live.com')])
# dict_items([('backer_id', 'zp659'), ('cf_id', 1572), ('name', 'Zeno Pruneau'), ('email', 'zpruneau@gmail.com')])
# dict_items([('backer_id', 'de758'), ('cf_id', 1114), ('name', 'Devon Epifano'), ('email', 'depifano@protonmail.com')])
# dict_items([('backer_id', 'jb896'), ('cf_id', 65), ('name', 'Jarrett Barrera'), ('email', 'jbarrera@gmail.com')])
# dict_items([('backer_id', 'wb355'), ('cf_id', 238), ('name', 'Walburg Burris'), ('email', 'wburris@outlook.com')])
# dict_items([('backer_id', 'rd560'), ('cf_id', 65), ('name', 'Raffaela Darras'), ('email', 'rdarras@gmail.com')])
# dict_items([('backer_id', 'er574'), ('cf_id', 1572), ('name', 'Eli Resta'), ('email', 'eresta@outlook.com')])
# dict_items([('backer_id', 'jc163'), ('cf_id', 65), ('name', 'Jin Chen'), ('email', 'jchen@outlook.com')])
# dict_items([('backer_id', 'kb942'), ('cf_id', 1114), ('name', 'Katja Butler'), ('email', 'kbutler@protonmail.com')])
# dict_items([('backer_id', 'af969'), ('cf_id', 563), ('name', 'Allegra Fiedler'), ('email', 'afiedler@yandex.com')])
# dict_items([('backer_id', 'bp212'), ('cf_id', 1572), ('name', 'Benton Pereira'), ('email', 'bpereira@live.com')])
# dict_items([('backer_id', 'tc947'), ('cf_id', 65), ('name', 'Tesha Carpinello'), ('email', 'tcarpinello@outlook.com')])
# dict_items([('backer_id', 'ak106'), ('cf_id', 1572), ('name', 'Anneli Kaufman'), ('email', 'akaufman@outlook.com')])
# dict_items([('backer_id', 'mr294'), ('cf_id', 1572), ('name', 'Merle Rowe'), ('email', 'mrowe@yahoo.com')])
# dict_items([('backer_id', 'bb365'), ('cf_id', 65), ('name', 'Bev Bellotti'), ('email', 'bbellotti@yandex.com')])
# dict_items([('backer_id', 'bj274'), ('cf_id', 65), ('name', 'Blake Jenkins'), ('email', 'bjenkins@outlook.com')])
# dict_items([('backer_id', 'qw345'), ('cf_id', 1572), ('name', 'Qiana Washington'), ('email', 'qwashington@gmail.com')])
# dict_items([('backer_id', 'ra925'), ('cf_id', 65), ('name', 'Rayane Adam'), ('email', 'radam@live.com')])
# dict_items([('backer_id', 'pg824'), ('cf_id', 968), ('name', 'Petronella Guilbaud'), ('email', 'pguilbaud@outlook.com')])
# dict_items([('backer_id', 'ef414'), ('cf_id', 65), ('name', 'Elodia Forgione'), ('email', 'eforgione@gmail.com')])
# dict_items([('backer_id', 'rp650'), ('cf_id', 238), ('name', 'Ryan Potts'), ('email', 'rpotts@protonmail.com')])
# dict_items([('backer_id', 'se972'), ('cf_id', 1114), ('name', 'Sigmund Everett'), ('email', 'severett@yahoo.com')])
# dict_items([('backer_id', 'sd958'), ('cf_id', 65), ('name', 'Serafina Desroches'), ('email', 'sdesroches@yahoo.com')])
# dict_items([('backer_id', 'mb304'), ('cf_id', 65), ('name', 'Murray Barrese'), ('email', 'mbarrese@yandex.com')])
# dict_items([('backer_id', 'lr409'), ('cf_id', 563), ('name', 'Luis Roberts'), ('email', 'lroberts@protonmail.com')])
# dict_items([('backer_id', 'fm559'), ('cf_id', 65), ('name', 'Felicia Mcneil'), ('email', 'fmcneil@outlook.com')])
# dict_items([('backer_id', 'wd714'), ('cf_id', 65), ('name', 'Willette Dattoli'), ('email', 'wdattoli@outlook.com')])
# dict_items([('backer_id', 'ls638'), ('cf_id', 1572), ('name', 'Lucas Stephens'), ('email', 'lstephens@protonmail.com')])
# dict_items([('backer_id', 'am362'), ('cf_id', 65), ('name', 'Amo Moses'), ('email', 'amoses@outlook.com')])
# dict_items([('backer_id', 'ta190'), ('cf_id', 563), ('name', 'Tandy Acker'), ('email', 'tacker@outlook.com')])
# dict_items([('backer_id', 'rb753'), ('cf_id', 65), ('name', 'Rolf Biron'), ('email', 'rbiron@outlook.com')])
# dict_items([('backer_id', 'cc594'), ('cf_id', 65), ('name', 'Catharina Cappella'), ('email', 'ccappella@gmail.com')])
# dict_items([('backer_id', 'vh915'), ('cf_id', 65), ('name', 'Virgilio Hyde'), ('email', 'vhyde@live.com')])
# dict_items([('backer_id', 'og539'), ('cf_id', 65), ('name', 'Ollie Gwerder'), ('email', 'ogwerder@yandex.com')])
# dict_items([('backer_id', 'dd470'), ('cf_id', 1911), ('name', 'Daniela Demers'), ('email', 'ddemers@yahoo.com')])
# dict_items([('backer_id', 'ap718'), ('cf_id', 238), ('name', 'Angel Peragine'), ('email', 'aperagine@live.com')])
# dict_items([('backer_id', 'vw158'), ('cf_id', 1572), ('name', 'Vicenzo Wells'), ('email', 'vwells@yandex.com')])
# dict_items([('backer_id', 'fh696'), ('cf_id', 2284), ('name', 'Fernanda Hodges'), ('email', 'fhodges@yandex.com')])
# dict_items([('backer_id', 'df617'), ('cf_id', 968), ('name', 'Darrin Fiedler'), ('email', 'dfiedler@yahoo.com')])
# dict_items([('backer_id', 'jv716'), ('cf_id', 65), ('name', 'Janine Veronesi'), ('email', 'jveronesi@gmail.com')])
# dict_items([('backer_id', 'tc807'), ('cf_id', 65), ('name', 'Terenzio Carver'), ('email', 'tcarver@gmail.com')])
# dict_items([('backer_id', 'me460'), ('cf_id', 563), ('name', 'Magali Eilerts'), ('email', 'meilerts@gmail.com')])
# dict_items([('backer_id', 'kp942'), ('cf_id', 1572), ('name', 'Kimber Puech'), ('email', 'kpuech@protonmail.com')])
# dict_items([('backer_id', 'xp438'), ('cf_id', 563), ('name', 'Xenia Pergola'), ('email', 'xpergola@yandex.com')])
# dict_items([('backer_id', 'af564'), ('cf_id', 1572), ('name', 'Arlena Fox'), ('email', 'afox@protonmail.com')])
# dict_items([('backer_id', 'wn746'), ('cf_id', 1114), ('name', 'Wilfred Nazzaro'), ('email', 'wnazzaro@yahoo.com')])
# dict_items([('backer_id', 'ad641'), ('cf_id', 1572), ('name', 'Angelina Decker'), ('email', 'adecker@yahoo.com')])
# dict_items([('backer_id', 'rs660'), ('cf_id', 65), ('name', 'Ressie Schneider'), ('email', 'rschneider@live.com')])
# dict_items([('backer_id', 'dp520'), ('cf_id', 65), ('name', 'Daine Pruneau'), ('email', 'dpruneau@outlook.com')])
# dict_items([('backer_id', 'me520'), ('cf_id', 65), ('name', 'Marius Emilio'), ('email', 'memilio@gmail.com')])
# dict_items([('backer_id', 'es977'), ('cf_id', 1572), ('name', 'Emily Stout'), ('email', 'estout@gmail.com')])
# dict_items([('backer_id', 'sd883'), ('cf_id', 3138), ('name', 'Shaunna Dreher'), ('email', 'sdreher@yahoo.com')])
# dict_items([('backer_id', 'tb283'), ('cf_id', 65), ('name', 'Toi Briere'), ('email', 'tbriere@outlook.com')])
# dict_items([('backer_id', 'eb415'), ('cf_id', 65), ('name', 'Eliodoro Black'), ('email', 'eblack@yahoo.com')])
# dict_items([('backer_id', 'fb116'), ('cf_id', 1572), ('name', 'Faustino Burgstaller'), ('email', 'fburgstaller@outlook.com')])
# dict_items([('backer_id', 'jb391'), ('cf_id', 1572), ('name', 'Jeramy Benard'), ('email', 'jbenard@yandex.com')])
# dict_items([('backer_id', 'ac624'), ('cf_id', 563), ('name', 'Annika Curtis'), ('email', 'acurtis@live.com')])
# dict_items([('backer_id', 'kc104'), ('cf_id', 65), ('name', 'Kelia Campbell'), ('email', 'kcampbell@protonmail.com')])
# dict_items([('backer_id', 'dg582'), ('cf_id', 65), ('name', 'Dario Gerst'), ('email', 'dgerst@protonmail.com')])
# dict_items([('backer_id', 'mb933'), ('cf_id', 1572), ('name', 'Maryetta Bussa'), ('email', 'mbussa@yahoo.com')])
# dict_items([('backer_id', 'em898'), ('cf_id', 65), ('name', 'Emerich Mccoy'), ('email', 'emccoy@live.com')])
# dict_items([('backer_id', 'tw982'), ('cf_id', 968), ('name', 'Timothe Wilder'), ('email', 'twilder@yandex.com')])
# dict_items([('backer_id', 'ab575'), ('cf_id', 65), ('name', 'Amadore Breitbarth'), ('email', 'abreitbarth@protonmail.com')])
# dict_items([('backer_id', 'dg744'), ('cf_id', 1572), ('name', 'Dave Gaillard'), ('email', 'dgaillard@live.com')])
# dict_items([('backer_id', 'cj442'), ('cf_id', 1572), ('name', 'Catrin Joseph'), ('email', 'cjoseph@live.com')])
# dict_items([('backer_id', 'lo117'), ('cf_id', 65), ('name', 'Laverne Ortega'), ('email', 'lortega@yandex.com')])
# dict_items([('backer_id', 'bg270'), ('cf_id', 65), ('name', 'Bulah Guay'), ('email', 'bguay@yandex.com')])
# dict_items([('backer_id', 'jc692'), ('cf_id', 65), ('name', 'Jae Castellucci'), ('email', 'jcastellucci@yahoo.com')])
# dict_items([('backer_id', 'jf750'), ('cf_id', 1572), ('name', 'Joseph Freeman'), ('email', 'jfreeman@live.com')])
# dict_items([('backer_id', 'lr317'), ('cf_id', 968), ('name', 'Lena Robbins'), ('email', 'lrobbins@live.com')])
# dict_items([('backer_id', 'cp253'), ('cf_id', 65), ('name', 'Charley Petitjean'), ('email', 'cpetitjean@yandex.com')])
# dict_items([('backer_id', 'vv330'), ('cf_id', 65), ('name', 'Veronika Vesco'), ('email', 'vvesco@live.com')])
# dict_items([('backer_id', 'ch724'), ('cf_id', 1572), ('name', 'Calandra Hofmeister'), ('email', 'chofmeister@protonmail.com')])
# dict_items([('backer_id', 'dm121'), ('cf_id', 65), ('name', 'Devon Marques'), ('email', 'dmarques@yandex.com')])
# dict_items([('backer_id', 'lc141'), ('cf_id', 65), ('name', 'Leon Carson'), ('email', 'lcarson@gmail.com')])
# dict_items([('backer_id', 'am966'), ('cf_id', 65), ('name', 'Adelrico Meadows'), ('email', 'ameadows@gmail.com')])
# dict_items([('backer_id', 'ab249'), ('cf_id', 65), ('name', 'Adel Becke'), ('email', 'abecke@yahoo.com')])
# dict_items([('backer_id', 'mb828'), ('cf_id', 65), ('name', 'Mariya Babin'), ('email', 'mbabin@outlook.com')])
# dict_items([('backer_id', 'pu317'), ('cf_id', 65), ('name', 'Peg Urciuoli'), ('email', 'purciuoli@yandex.com')])
# dict_items([('backer_id', 'cb515'), ('cf_id', 1572), ('name', 'Clarita Barron'), ('email', 'cbarron@protonmail.com')])
# dict_items([('backer_id', 'so203'), ('cf_id', 563), ('name', 'Silvia Olson'), ('email', 'solson@gmail.com')])
# dict_items([('backer_id', 'aa284'), ('cf_id', 65), ('name', 'Armand Arnold'), ('email', 'aarnold@live.com')])
# dict_items([('backer_id', 'sc143'), ('cf_id', 65), ('name', 'Sueann Casciani'), ('email', 'scasciani@outlook.com')])
# dict_items([('backer_id', 'je217'), ('cf_id', 65), ('name', 'Jc Elliott'), ('email', 'jelliott@yandex.com')])
# dict_items([('backer_id', 'ke511'), ('cf_id', 1114), ('name', 'Kalet Eaton'), ('email', 'keaton@outlook.com')])
# dict_items([('backer_id', 'oa673'), ('cf_id', 563), ('name', 'Ottavia Abraham'), ('email', 'oabraham@yandex.com')])
# dict_items([('backer_id', 'sc432'), ('cf_id', 968), ('name', 'Swanhild Cameron'), ('email', 'scameron@yandex.com')])
# dict_items([('backer_id', 'aj655'), ('cf_id', 65), ('name', 'Alessandrina Jollenbeck'), ('email', 'ajollenbeck@outlook.com')])
# dict_items([('backer_id', 'jp351'), ('cf_id', 968), ('name', 'Jamison Perona'), ('email', 'jperona@live.com')])
# dict_items([('backer_id', 'lj758'), ('cf_id', 968), ('name', 'Louis Justice'), ('email', 'ljustice@yahoo.com')])
# dict_items([('backer_id', 'ps794'), ('cf_id', 1572), ('name', 'Pablo Sykes'), ('email', 'psykes@yandex.com')])
# dict_items([('backer_id', 'nb202'), ('cf_id', 1572), ('name', 'Nek Blecher'), ('email', 'nblecher@yahoo.com')])
# dict_items([('backer_id', 'gp356'), ('cf_id', 968), ('name', 'Guadalupe Pannone'), ('email', 'gpannone@outlook.com')])
# dict_items([('backer_id', 'rb945'), ('cf_id', 1572), ('name', 'Ramona Berg'), ('email', 'rberg@yandex.com')])
# dict_items([('backer_id', 'gw991'), ('cf_id', 65), ('name', 'Gioconda Webster'), ('email', 'gwebster@live.com')])
# dict_items([('backer_id', 'gb896'), ('cf_id', 910), ('name', 'George Bauers'), ('email', 'gbauers@yahoo.com')])
# dict_items([('backer_id', 'jm345'), ('cf_id', 563), ('name', 'Julian Maillot'), ('email', 'jmaillot@yandex.com')])
# dict_items([('backer_id', 'ma565'), ('cf_id', 1911), ('name', 'Melusina Asti'), ('email', 'masti@yandex.com')])
# dict_items([('backer_id', 'oh728'), ('cf_id', 65), ('name', 'Ornella Hester'), ('email', 'ohester@live.com')])
# dict_items([('backer_id', 'dg119'), ('cf_id', 1572), ('name', 'Dione Gass'), ('email', 'dgass@yandex.com')])
# dict_items([('backer_id', 'kd744'), ('cf_id', 968), ('name', 'Konrad Damone'), ('email', 'kdamone@yandex.com')])
# dict_items([('backer_id', 'ww138'), ('cf_id', 65), ('name', 'Walid Woods'), ('email', 'wwoods@protonmail.com')])
# dict_items([('backer_id', 'gb135'), ('cf_id', 1572), ('name', 'Giana Blevins'), ('email', 'gblevins@protonmail.com')])
# dict_items([('backer_id', 'lp541'), ('cf_id', 563), ('name', 'Lino Pires'), ('email', 'lpires@yandex.com')])
# dict_items([('backer_id', 'hm752'), ('cf_id', 65), ('name', 'Helmina Mosco'), ('email', 'hmosco@outlook.com')])
# dict_items([('backer_id', 'ib452'), ('cf_id', 1911), ('name', 'Inaya Barton'), ('email', 'ibarton@yandex.com')])
# dict_items([('backer_id', 'fc303'), ('cf_id', 65), ('name', 'Francesca Chambers'), ('email', 'fchambers@protonmail.com')])
# dict_items([('backer_id', 'kb141'), ('cf_id', 1114), ('name', 'Kenisha Bergfalk'), ('email', 'kbergfalk@outlook.com')])
# dict_items([('backer_id', 'is909'), ('cf_id', 65), ('name', 'Ismael Sarrazin'), ('email', 'isarrazin@live.com')])
# dict_items([('backer_id', 'hv133'), ('cf_id', 968), ('name', 'Holger Vitiello'), ('email', 'hvitiello@protonmail.com')])
# dict_items([('backer_id', 'nm163'), ('cf_id', 65), ('name', 'Nayla Melendez'), ('email', 'nmelendez@yahoo.com')])
# dict_items([('backer_id', 'cs899'), ('cf_id', 65), ('name', 'Camila Sciarretta'), ('email', 'csciarretta@yandex.com')])
# dict_items([('backer_id', 'lh190'), ('cf_id', 65), ('name', 'Lucia Hatfield'), ('email', 'lhatfield@gmail.com')])
# dict_items([('backer_id', 'as260'), ('cf_id', 65), ('name', 'Annetta Scholz'), ('email', 'ascholz@live.com')])
# dict_items([('backer_id', 'db149'), ('cf_id', 65), ('name', 'Demarcus Barthelemy'), ('email', 'dbarthelemy@gmail.com')])
# dict_items([('backer_id', 'cg952'), ('cf_id', 563), ('name', 'Clifton Garibaldi'), ('email', 'cgaribaldi@live.com')])
# dict_items([('backer_id', 'tm490'), ('cf_id', 65), ('name', 'Tobias Mcintyre'), ('email', 'tmcintyre@gmail.com')])
# dict_items([('backer_id', 'lt569'), ('cf_id', 65), ('name', 'Lalie Tyler'), ('email', 'ltyler@outlook.com')])
# dict_items([('backer_id', 'ce212'), ('cf_id', 65), ('name', 'Cristiano Everhart'), ('email', 'ceverhart@yandex.com')])
# dict_items([('backer_id', 'sr285'), ('cf_id', 2284), ('name', 'Shirl Rochon'), ('email', 'srochon@live.com')])
# dict_items([('backer_id', 'tc231'), ('cf_id', 2882), ('name', 'Treena Ciampa'), ('email', 'tciampa@yandex.com')])
# dict_items([('backer_id', 'll471'), ('cf_id', 968), ('name', 'Luther Leonard'), ('email', 'lleonard@gmail.com')])
# dict_items([('backer_id', 'aa130'), ('cf_id', 65), ('name', 'Affonso Abraham'), ('email', 'aabraham@outlook.com')])
# dict_items([('backer_id', 'sb241'), ('cf_id', 563), ('name', 'So Boilard'), ('email', 'sboilard@yandex.com')])
# dict_items([('backer_id', 'lb909'), ('cf_id', 968), ('name', 'Luther Barberi'), ('email', 'lbarberi@yahoo.com')])
# dict_items([('backer_id', 'lw976'), ('cf_id', 910), ('name', 'Leuther Webb'), ('email', 'lwebb@gmail.com')])
# dict_items([('backer_id', 'ab143'), ('cf_id', 1114), ('name', 'Abel Burke'), ('email', 'aburke@outlook.com')])
# dict_items([('backer_id', 'cg893'), ('cf_id', 65), ('name', 'Calogero Geiger'), ('email', 'cgeiger@outlook.com')])
# dict_items([('backer_id', 'nl492'), ('cf_id', 65), ('name', 'Nelson Lemire'), ('email', 'nlemire@yahoo.com')])
# dict_items([('backer_id', 'nc285'), ('cf_id', 1572), ('name', 'Nadene Cartelli'), ('email', 'ncartelli@live.com')])
# dict_items([('backer_id', 'ct703'), ('cf_id', 65), ('name', 'Calvin Tate'), ('email', 'ctate@yandex.com')])
# dict_items([('backer_id', 'aw876'), ('cf_id', 1572), ('name', 'Axel Watts'), ('email', 'awatts@protonmail.com')])
# dict_items([('backer_id', 'af506'), ('cf_id', 563), ('name', 'Alda Feigenbaum'), ('email', 'afeigenbaum@live.com')])
# dict_items([('backer_id', 'es282'), ('cf_id', 65), ('name', 'Elena Shields'), ('email', 'eshields@outlook.com')])
# dict_items([('backer_id', 'co633'), ('cf_id', 65), ('name', 'Circinus Odom'), ('email', 'codom@yahoo.com')])
# dict_items([('backer_id', 'mh163'), ('cf_id', 65), ('name', 'Marietta Holzmann'), ('email', 'mholzmann@yandex.com')])
# dict_items([('backer_id', 'pc978'), ('cf_id', 65), ('name', 'Peg Corriveau'), ('email', 'pcorriveau@protonmail.com')])
# dict_items([('backer_id', 'gc386'), ('cf_id', 2882), ('name', 'Gregory Cianciolo'), ('email', 'gcianciolo@live.com')])
# dict_items([('backer_id', 'nl252'), ('cf_id', 1114), ('name', 'Nolhan Lindsey'), ('email', 'nlindsey@live.com')])
# dict_items([('backer_id', 'rb829'), ('cf_id', 1572), ('name', 'Romero Blau'), ('email', 'rblau@gmail.com')])
# dict_items([('backer_id', 'gl884'), ('cf_id', 65), ('name', 'Genaro Larose'), ('email', 'glarose@yahoo.com')])
# dict_items([('backer_id', 'og404'), ('cf_id', 65), ('name', 'Oralee Garbarino'), ('email', 'ogarbarino@live.com')])
# dict_items([('backer_id', 'kr745'), ('cf_id', 1911), ('name', 'Karsten Riggs'), ('email', 'kriggs@live.com')])
# dict_items([('backer_id', 'jc104'), ('cf_id', 238), ('name', 'Joris Cline'), ('email', 'jcline@yandex.com')])
# dict_items([('backer_id', 'th958'), ('cf_id', 968), ('name', 'Tasha Holzknecht'), ('email', 'tholzknecht@live.com')])
# dict_items([('backer_id', 'jb207'), ('cf_id', 65), ('name', 'Jarrett Beaumont'), ('email', 'jbeaumont@yandex.com')])
# dict_items([('backer_id', 'lm386'), ('cf_id', 65), ('name', 'Laverne Maddalone'), ('email', 'lmaddalone@yahoo.com')])
# dict_items([('backer_id', 'ic277'), ('cf_id', 968), ('name', 'Imre Carlson'), ('email', 'icarlson@live.com')])
# dict_items([('backer_id', 'ab714'), ('cf_id', 968), ('name', 'Angel Brennan'), ('email', 'abrennan@live.com')])
# dict_items([('backer_id', 'jm813'), ('cf_id', 2488), ('name', 'Jinny Michaud'), ('email', 'jmichaud@live.com')])
# dict_items([('backer_id', 'ma226'), ('cf_id', 238), ('name', 'Maryam Armellino'), ('email', 'marmellino@outlook.com')])
# dict_items([('backer_id', 'lm154'), ('cf_id', 1114), ('name', 'Lyle Massey'), ('email', 'lmassey@yandex.com')])
# dict_items([('backer_id', 'pp209'), ('cf_id', 65), ('name', 'Peppe Pohl'), ('email', 'ppohl@gmail.com')])
# dict_items([('backer_id', 'ss320'), ('cf_id', 1114), ('name', 'Shakita Sabatier'), ('email', 'ssabatier@gmail.com')])
# dict_items([('backer_id', 'lb805'), ('cf_id', 1572), ('name', 'Lynwood Bozza'), ('email', 'lbozza@yahoo.com')])
# dict_items([('backer_id', 'sf196'), ('cf_id', 968), ('name', 'Siglinde Flores'), ('email', 'sflores@live.com')])
# dict_items([('backer_id', 'jc350'), ('cf_id', 1572), ('name', 'Jaden Castro'), ('email', 'jcastro@outlook.com')])
# dict_items([('backer_id', 'bh958'), ('cf_id', 1114), ('name', 'Bartolo Haupt'), ('email', 'bhaupt@outlook.com')])
# dict_items([('backer_id', 'vp800'), ('cf_id', 65), ('name', 'Venetta Perugini'), ('email', 'vperugini@gmail.com')])
# dict_items([('backer_id', 'ec148'), ('cf_id', 1572), ('name', 'Ellsworth Clements'), ('email', 'eclements@yahoo.com')])
# dict_items([('backer_id', 'ha431'), ('cf_id', 65), ('name', 'Harbin Alston'), ('email', 'halston@outlook.com')])
# dict_items([('backer_id', 'sw972'), ('cf_id', 65), ('name', 'Syrine Walter'), ('email', 'swalter@yahoo.com')])
# dict_items([('backer_id', 'sb891'), ('cf_id', 1572), ('name', 'Sansone Bisaillon'), ('email', 'sbisaillon@protonmail.com')])
# dict_items([('backer_id', 'sf735'), ('cf_id', 1114), ('name', 'Shantay Fiori'), ('email', 'sfiori@protonmail.com')])
# dict_items([('backer_id', 'mp538'), ('cf_id', 563), ('name', 'Mary Prince'), ('email', 'mprince@protonmail.com')])
# dict_items([('backer_id', 'cf904'), ('cf_id', 1572), ('name', 'Catrin Ferguson'), ('email', 'cferguson@gmail.com')])
# dict_items([('backer_id', 'gs818'), ('cf_id', 1572), ('name', 'Gianpiero Samson'), ('email', 'gsamson@yandex.com')])
# dict_items([('backer_id', 'ra782'), ('cf_id', 1572), ('name', 'Robert Altieri'), ('email', 'raltieri@protonmail.com')])
# dict_items([('backer_id', 'yc752'), ('cf_id', 1911), ('name', 'Yvone Capodanno'), ('email', 'ycapodanno@live.com')])
# dict_items([('backer_id', 'le377'), ('cf_id', 563), ('name', 'Lucetta Eichel'), ('email', 'leichel@protonmail.com')])
# dict_items([('backer_id', 'ja139'), ('cf_id', 968), ('name', 'Jalisa Anastasi'), ('email', 'janastasi@yandex.com')])
# dict_items([('backer_id', 'jf881'), ('cf_id', 65), ('name', 'Jessi Farley'), ('email', 'jfarley@yahoo.com')])
# dict_items([('backer_id', 'am638'), ('cf_id', 1114), ('name', 'Adolph Merrill'), ('email', 'amerrill@gmail.com')])
# dict_items([('backer_id', 'rh663'), ('cf_id', 65), ('name', 'Riyad Holst'), ('email', 'rholst@outlook.com')])
# dict_items([('backer_id', 'dl438'), ('cf_id', 238), ('name', 'Donatien Lefrancois'), ('email', 'dlefrancois@yandex.com')])
# dict_items([('backer_id', 'je184'), ('cf_id', 1114), ('name', 'Jere Evans'), ('email', 'jevans@outlook.com')])
# dict_items([('backer_id', 'xg938'), ('cf_id', 65), ('name', 'Xandi Glenn'), ('email', 'xglenn@live.com')])
# dict_items([('backer_id', 'mg208'), ('cf_id', 563), ('name', 'Marianne Geiger'), ('email', 'mgeiger@outlook.com')])
# dict_items([('backer_id', 'ag672'), ('cf_id', 65), ('name', 'Alonzo Gautier'), ('email', 'agautier@protonmail.com')])
# dict_items([('backer_id', 'sc991'), ('cf_id', 65), ('name', 'Santo Cornacchia'), ('email', 'scornacchia@yahoo.com')])
# dict_items([('backer_id', 'ar456'), ('cf_id', 238), ('name', 'Aleida Robertson'), ('email', 'arobertson@yahoo.com')])
# dict_items([('backer_id', 'an122'), ('cf_id', 65), ('name', 'Alexandra Nolan'), ('email', 'anolan@yandex.com')])
# dict_items([('backer_id', 'mh749'), ('cf_id', 65), ('name', 'Marina Habich'), ('email', 'mhabich@protonmail.com')])
# dict_items([('backer_id', 'ac765'), ('cf_id', 65), ('name', 'Agnella Cloutier'), ('email', 'acloutier@yahoo.com')])
# dict_items([('backer_id', 'ln560'), ('cf_id', 563), ('name', 'Loralee Nerone'), ('email', 'lnerone@live.com')])
# dict_items([('backer_id', 'dm881'), ('cf_id', 1114), ('name', 'Dot Moore'), ('email', 'dmoore@protonmail.com')])
# dict_items([('backer_id', 'wm699'), ('cf_id', 65), ('name', 'Wolf Morin'), ('email', 'wmorin@gmail.com')])
# dict_items([('backer_id', 'ca628'), ('cf_id', 1114), ('name', 'Ciel Augustin'), ('email', 'caugustin@yandex.com')])
# dict_items([('backer_id', 'ls538'), ('cf_id', 1114), ('name', 'Leontina Saucier'), ('email', 'lsaucier@live.com')])
# dict_items([('backer_id', 'kr958'), ('cf_id', 563), ('name', 'Kathern Rodriquez'), ('email', 'krodriquez@live.com')])
# dict_items([('backer_id', 'ad265'), ('cf_id', 65), ('name', 'Alder Dressler'), ('email', 'adressler@outlook.com')])
# dict_items([('backer_id', 'am627'), ('cf_id', 1572), ('name', 'Aroghetto Manza'), ('email', 'amanza@yahoo.com')])
# dict_items([('backer_id', 'rp666'), ('cf_id', 1572), ('name', 'Roberto Perry'), ('email', 'rperry@gmail.com')])
# dict_items([('backer_id', 'rs221'), ('cf_id', 65), ('name', 'Reena Shaw'), ('email', 'rshaw@protonmail.com')])
# dict_items([('backer_id', 'ma490'), ('cf_id', 65), ('name', 'Melina Abeln'), ('email', 'mabeln@yandex.com')])
# dict_items([('backer_id', 'xd210'), ('cf_id', 65), ('name', 'Xavier Delahaye'), ('email', 'xdelahaye@yahoo.com')])
# dict_items([('backer_id', 'mc413'), ('cf_id', 563), ('name', 'Moses Cece'), ('email', 'mcece@protonmail.com')])
# dict_items([('backer_id', 'ss568'), ('cf_id', 1572), ('name', 'Sheilah Shaw'), ('email', 'sshaw@yandex.com')])
# dict_items([('backer_id', 'dr174'), ('cf_id', 563), ('name', 'Daniela Rhodes'), ('email', 'drhodes@gmail.com')])
# dict_items([('backer_id', 'vb927'), ('cf_id', 563), ('name', 'Viviana Belhumeur'), ('email', 'vbelhumeur@protonmail.com')])
# dict_items([('backer_id', 'ms327'), ('cf_id', 65), ('name', 'Mireille Stanley'), ('email', 'mstanley@protonmail.com')])
# dict_items([('backer_id', 'lf675'), ('cf_id', 1911), ('name', 'Lynetta Frank'), ('email', 'lfrank@live.com')])
# dict_items([('backer_id', 'hb499'), ('cf_id', 65), ('name', 'Hermann Buckholtz'), ('email', 'hbuckholtz@gmail.com')])
# dict_items([('backer_id', 'lb187'), ('cf_id', 65), ('name', 'Leane Boulanger'), ('email', 'lboulanger@outlook.com')])
# dict_items([('backer_id', 'um200'), ('cf_id', 65), ('name', 'Ugo Mammone'), ('email', 'umammone@yahoo.com')])
# dict_items([('backer_id', 'gh932'), ('cf_id', 65), ('name', 'Gail Hewitt'), ('email', 'ghewitt@outlook.com')])
# dict_items([('backer_id', 'kl672'), ('cf_id', 65), ('name', 'Kermit Lowery'), ('email', 'klowery@gmail.com')])
# dict_items([('backer_id', 'ab491'), ('cf_id', 563), ('name', 'Alois Behrend'), ('email', 'abehrend@live.com')])
# dict_items([('backer_id', 'bb348'), ('cf_id', 1572), ('name', 'Bonito Bon'), ('email', 'bbon@live.com')])
# dict_items([('backer_id', 'jv337'), ('cf_id', 2882), ('name', 'Jacinda Verde'), ('email', 'jverde@yahoo.com')])
# dict_items([('backer_id', 'lh149'), ('cf_id', 65), ('name', 'Lloyd Holden'), ('email', 'lholden@outlook.com')])
# dict_items([('backer_id', 'kw599'), ('cf_id', 3138), ('name', 'Kurigunde Wolfe'), ('email', 'kwolfe@protonmail.com')])
# dict_items([('backer_id', 'mh683'), ('cf_id', 65), ('name', 'Marvin Hummel'), ('email', 'mhummel@yahoo.com')])
# dict_items([('backer_id', 'bm342'), ('cf_id', 65), ('name', 'Baiardo Maglione'), ('email', 'bmaglione@gmail.com')])
# dict_items([('backer_id', 'il539'), ('cf_id', 1114), ('name', 'Isaias Lyons'), ('email', 'ilyons@yahoo.com')])
# dict_items([('backer_id', 'jl327'), ('cf_id', 563), ('name', 'Johnnie Le'), ('email', 'jle@protonmail.com')])
# dict_items([('backer_id', 'wf249'), ('cf_id', 65), ('name', 'Walker Friedrich'), ('email', 'wfriedrich@live.com')])
# dict_items([('backer_id', 'ba539'), ('cf_id', 1572), ('name', 'Benedict Allen'), ('email', 'ballen@protonmail.com')])
# dict_items([('backer_id', 'sj553'), ('cf_id', 563), ('name', 'Sung Jordan'), ('email', 'sjordan@gmail.com')])
# dict_items([('backer_id', 'gb371'), ('cf_id', 563), ('name', 'Garfield Bonnard'), ('email', 'gbonnard@yahoo.com')])
# dict_items([('backer_id', 'hm715'), ('cf_id', 1572), ('name', 'Hansel Mecca'), ('email', 'hmecca@outlook.com')])
# dict_items([('backer_id', 'ec905'), ('cf_id', 1114), ('name', 'Emy Chapman'), ('email', 'echapman@gmail.com')])
# dict_items([('backer_id', 'lw634'), ('cf_id', 65), ('name', 'Lucetta Wilcox'), ('email', 'lwilcox@outlook.com')])
# dict_items([('backer_id', 'dh507'), ('cf_id', 65), ('name', 'Danial Hummel'), ('email', 'dhummel@yahoo.com')])
# dict_items([('backer_id', 'mr622'), ('cf_id', 65), ('name', 'Marion Ribeiro'), ('email', 'mribeiro@gmail.com')])
# dict_items([('backer_id', 'gs461'), ('cf_id', 1572), ('name', 'Gilbert Spaziani'), ('email', 'gspaziani@gmail.com')])
# dict_items([('backer_id', 'gb648'), ('cf_id', 563), ('name', 'Genevra Bentley'), ('email', 'gbentley@gmail.com')])
# dict_items([('backer_id', 'eo125'), ('cf_id', 563), ('name', 'Emilio Owen'), ('email', 'eowen@yahoo.com')])
# dict_items([('backer_id', 'rb185'), ('cf_id', 1572), ('name', 'Reid Borchard'), ('email', 'rborchard@gmail.com')])
# dict_items([('backer_id', 'og865'), ('cf_id', 563), ('name', 'Oscar Gallant'), ('email', 'ogallant@live.com')])
# dict_items([('backer_id', 'tr733'), ('cf_id', 563), ('name', 'Titouan Reginato'), ('email', 'treginato@live.com')])
# dict_items([('backer_id', 'ac323'), ('cf_id', 65), ('name', 'Aniella Coleman'), ('email', 'acoleman@yandex.com')])
# dict_items([('backer_id', 'lo326'), ('cf_id', 1911), ('name', 'Laurena Ortiz'), ('email', 'lortiz@live.com')])
# dict_items([('backer_id', 'hc889'), ('cf_id', 563), ('name', 'Helaine Carignan'), ('email', 'hcarignan@live.com')])
# dict_items([('backer_id', 'hv904'), ('cf_id', 65), ('name', 'Harold Vinci'), ('email', 'hvinci@yandex.com')])
# dict_items([('backer_id', 'md370'), ('cf_id', 1114), ('name', 'Monte Dillon'), ('email', 'mdillon@yandex.com')])
# dict_items([('backer_id', 'sb514'), ('cf_id', 1572), ('name', 'Shondra Bach'), ('email', 'sbach@protonmail.com')])
# dict_items([('backer_id', 'sf324'), ('cf_id', 1572), ('name', 'Saul Fayolle'), ('email', 'sfayolle@yahoo.com')])
# dict_items([('backer_id', 'eb537'), ('cf_id', 968), ('name', 'Etienne Buonopane'), ('email', 'ebuonopane@live.com')])
# dict_items([('backer_id', 'bn189'), ('cf_id', 65), ('name', 'Beatrix Noble'), ('email', 'bnoble@protonmail.com')])
# dict_items([('backer_id', 'sc931'), ('cf_id', 1114), ('name', 'Seema Cherry'), ('email', 'scherry@protonmail.com')])
# dict_items([('backer_id', 'th234'), ('cf_id', 65), ('name', 'Toby Haupt'), ('email', 'thaupt@gmail.com')])
# dict_items([('backer_id', 'lb460'), ('cf_id', 1114), ('name', 'Lamar Berger'), ('email', 'lberger@yahoo.com')])
# dict_items([('backer_id', 'sp161'), ('cf_id', 563), ('name', 'Suzanne Paniccia'), ('email', 'spaniccia@gmail.com')])
# dict_items([('backer_id', 'bm476'), ('cf_id', 238), ('name', 'Bianka Massey'), ('email', 'bmassey@yandex.com')])
# dict_items([('backer_id', 'ta391'), ('cf_id', 563), ('name', 'Tomika Andrews'), ('email', 'tandrews@protonmail.com')])
# dict_items([('backer_id', 'bm966'), ('cf_id', 1572), ('name', 'Bertha Maurin'), ('email', 'bmaurin@protonmail.com')])
# dict_items([('backer_id', 'nm952'), ('cf_id', 1911), ('name', 'Nyla Mcconnell'), ('email', 'nmcconnell@outlook.com')])
# dict_items([('backer_id', 'rg418'), ('cf_id', 65), ('name', 'Ronny Gotti'), ('email', 'rgotti@gmail.com')])
# dict_items([('backer_id', 'rm381'), ('cf_id', 65), ('name', 'Rollin Magne'), ('email', 'rmagne@yahoo.com')])
# dict_items([('backer_id', 'ab162'), ('cf_id', 65), ('name', 'Anae Buzzeo'), ('email', 'abuzzeo@protonmail.com')])
# dict_items([('backer_id', 'gf246'), ('cf_id', 1114), ('name', 'Giada Fisher'), ('email', 'gfisher@protonmail.com')])
# dict_items([('backer_id', 'ch750'), ('cf_id', 1114), ('name', 'Cletus Hatfield'), ('email', 'chatfield@yandex.com')])
# dict_items([('backer_id', 'jg803'), ('cf_id', 1114), ('name', 'Jeffrey Gerber'), ('email', 'jgerber@yahoo.com')])
# dict_items([('backer_id', 'pl955'), ('cf_id', 563), ('name', 'Philomena Leduc'), ('email', 'pleduc@yandex.com')])
# dict_items([('backer_id', 'bc578'), ('cf_id', 968), ('name', 'Bellissa Carpenter'), ('email', 'bcarpenter@yahoo.com')])
# dict_items([('backer_id', 'np469'), ('cf_id', 65), ('name', 'Nadene Pittman'), ('email', 'npittman@yahoo.com')])
# ...
# dict_items([('backer_id', 'ar944'), ('cf_id', 65), ('name', 'Andera Rolland'), ('email', 'arolland@yahoo.com')])
# dict_items([('backer_id', 'lf592'), ('cf_id', 968), ('name', 'Laurine Ferguson'), ('email', 'lferguson@yahoo.com')])
# dict_items([('backer_id', 'cb502'), ('cf_id', 910), ('name', 'Christian Bauer'), ('email', 'cbauer@gmail.com')])
# dict_items([('backer_id', 'kh921'), ('cf_id', 1572), ('name', 'Kermit Humbert'), ('email', 'khumbert@outlook.com')])
# dict_items([('backer_id', 'ci145'), ('cf_id', 1114), ('name', 'Carson Impastato'), ('email', 'cimpastato@live.com')])
# dict_items([('backer_id', 'cr508'), ('cf_id', 2882), ('name', 'Cecilie Rodriguez'), ('email', 'crodriguez@protonmail.com')])
# dict_items([('backer_id', 'af138'), ('cf_id', 563), ('name', 'Annalisa Feigenbaum'), ('email', 'afeigenbaum@protonmail.com')])
# dict_items([('backer_id', 'mv493'), ('cf_id', 968), ('name', 'Marine Verona'), ('email', 'mverona@live.com')])
# dict_items([('backer_id', 'ww245'), ('cf_id', 65), ('name', 'Walter Webster'), ('email', 'wwebster@yandex.com')])
# dict_items([('backer_id', 'kf583'), ('cf_id', 65), ('name', 'Kristina Farrell'), ('email', 'kfarrell@live.com')])
# dict_items([('backer_id', 'bh618'), ('cf_id', 65), ('name', 'Blaise Herbert'), ('email', 'bherbert@protonmail.com')])
# dict_items([('backer_id', 'pp126'), ('cf_id', 65), ('name', 'Prima Pilote'), ('email', 'ppilote@live.com')])
# dict_items([('backer_id', 'kf282'), ('cf_id', 910), ('name', 'Kevin Ford'), ('email', 'kford@yahoo.com')])
# dict_items([('backer_id', 'hb505'), ('cf_id', 1911), ('name', 'Holland Brinkerhoff'), ('email', 'hbrinkerhoff@live.com')])
# dict_items([('backer_id', 'rc421'), ('cf_id', 65), ('name', 'Rosabel Cardon'), ('email', 'rcardon@protonmail.com')])
# dict_items([('backer_id', 'cc595'), ('cf_id', 65), ('name', 'Clifton Cicio'), ('email', 'ccicio@yahoo.com')])
# dict_items([('backer_id', 'ms810'), ('cf_id', 948), ('name', 'Montrell Schmitt'), ('email', 'mschmitt@outlook.com')])
# dict_items([('backer_id', 'cc343'), ('cf_id', 65), ('name', 'Clemente Chauvet'), ('email', 'cchauvet@outlook.com')])
# dict_items([('backer_id', 'mv448'), ('cf_id', 65), ('name', 'Marcos Viel'), ('email', 'mviel@outlook.com')])
# dict_items([('backer_id', 'ib668'), ('cf_id', 65), ('name', 'Idell Blackburn'), ('email', 'iblackburn@gmail.com')])
# dict_items([('backer_id', 'hb393'), ('cf_id', 1572), ('name', 'Hermine Bates'), ('email', 'hbates@yandex.com')])
# dict_items([('backer_id', 'ah345'), ('cf_id', 65), ('name', 'Armand Hall'), ('email', 'ahall@live.com')])
# dict_items([('backer_id', 'jc355'), ('cf_id', 1572), ('name', 'Julian Cardenas'), ('email', 'jcardenas@yandex.com')])
# dict_items([('backer_id', 'sf571'), ('cf_id', 65), ('name', 'Shon Frost'), ('email', 'sfrost@live.com')])
# dict_items([('backer_id', 'dl914'), ('cf_id', 968), ('name', 'David Lebas'), ('email', 'dlebas@protonmail.com')])
# dict_items([('backer_id', 'ag220'), ('cf_id', 1114), ('name', 'Angelina Guida'), ('email', 'aguida@gmail.com')])
# dict_items([('backer_id', 'nh963'), ('cf_id', 65), ('name', 'Nicoletta Hood'), ('email', 'nhood@protonmail.com')])
# dict_items([('backer_id', 'bb345'), ('cf_id', 65), ('name', 'Beata Bischoffs'), ('email', 'bbischoffs@gmail.com')])
# dict_items([('backer_id', 'sp482'), ('cf_id', 968), ('name', 'Sonia Panozzo'), ('email', 'spanozzo@protonmail.com')])
# dict_items([('backer_id', 'ac807'), ('cf_id', 1572), ('name', 'Albinia Colon'), ('email', 'acolon@gmail.com')])
# dict_items([('backer_id', 'lp322'), ('cf_id', 65), ('name', 'Logan Pitts'), ('email', 'lpitts@protonmail.com')])
# dict_items([('backer_id', 'th942'), ('cf_id', 65), ('name', 'Tom Hofmeister'), ('email', 'thofmeister@outlook.com')])
# dict_items([('backer_id', 'lc707'), ('cf_id', 563), ('name', 'Lou Cordaro'), ('email', 'lcordaro@outlook.com')])
# dict_items([('backer_id', 'ml646'), ('cf_id', 968), ('name', 'Meriem Lindsey'), ('email', 'mlindsey@protonmail.com')])
# dict_items([('backer_id', 'ih987'), ('cf_id', 238), ('name', 'Imelda Haynes'), ('email', 'ihaynes@yahoo.com')])
# dict_items([('backer_id', 'ah213'), ('cf_id', 1911), ('name', 'Annika Houk'), ('email', 'ahouk@protonmail.com')])
# dict_items([('backer_id', 'nm664'), ('cf_id', 65), ('name', 'Natalya Marques'), ('email', 'nmarques@yahoo.com')])
# dict_items([('backer_id', 'wb613'), ('cf_id', 65), ('name', 'William Botticelli'), ('email', 'wbotticelli@protonmail.com')])
# dict_items([('backer_id', 'aa174'), ('cf_id', 65), ('name', 'Alix Adkins'), ('email', 'aadkins@outlook.com')])
# dict_items([('backer_id', 'gw422'), ('cf_id', 65), ('name', 'Gianpaolo Wall'), ('email', 'gwall@yahoo.com')])
# dict_items([('backer_id', 'bf209'), ('cf_id', 968), ('name', 'Bronwyn Fuchs'), ('email', 'bfuchs@live.com')])
# dict_items([('backer_id', 'np290'), ('cf_id', 65), ('name', 'Neville Patenaude'), ('email', 'npatenaude@yandex.com')])
# dict_items([('backer_id', 'rc255'), ('cf_id', 65), ('name', 'Rico Cervelli'), ('email', 'rcervelli@protonmail.com')])
# dict_items([('backer_id', 'as439'), ('cf_id', 1572), ('name', 'Aramis Sutton'), ('email', 'asutton@live.com')])
# dict_items([('backer_id', 'fh603'), ('cf_id', 65), ('name', 'Fulvio Hatfield'), ('email', 'fhatfield@protonmail.com')])
# dict_items([('backer_id', 'od396'), ('cf_id', 968), ('name', 'Oswaldo Dirks'), ('email', 'odirks@yahoo.com')])
# dict_items([('backer_id', 'rd571'), ('cf_id', 563), ('name', 'Raymond Despres'), ('email', 'rdespres@protonmail.com')])
# dict_items([('backer_id', 'to793'), ('cf_id', 968), ('name', 'Titouan Olsen'), ('email', 'tolsen@yandex.com')])
# dict_items([('backer_id', 'yp317'), ('cf_id', 563), ('name', 'Yee Pohl'), ('email', 'ypohl@yandex.com')])
# dict_items([('backer_id', 'hm785'), ('cf_id', 65), ('name', 'Hilda Magnin'), ('email', 'hmagnin@gmail.com')])
# dict_items([('backer_id', 'bb745'), ('cf_id', 65), ('name', 'Brunetta Battista'), ('email', 'bbattista@protonmail.com')])
# dict_items([('backer_id', 'aj256'), ('cf_id', 65), ('name', 'Ali Johnson'), ('email', 'ajohnson@yandex.com')])
# dict_items([('backer_id', 'gb612'), ('cf_id', 65), ('name', 'Garen Balestrieri'), ('email', 'gbalestrieri@live.com')])
# dict_items([('backer_id', 'jg104'), ('cf_id', 1911), ('name', 'Jerald Gros'), ('email', 'jgros@live.com')])
# dict_items([('backer_id', 'am940'), ('cf_id', 563), ('name', 'Ali Manzella'), ('email', 'amanzella@yahoo.com')])
# dict_items([('backer_id', 'kl379'), ('cf_id', 968), ('name', 'Kunigunde Lawrence'), ('email', 'klawrence@protonmail.com')])
# dict_items([('backer_id', 'jk118'), ('cf_id', 65), ('name', 'Jesper Kinney'), ('email', 'jkinney@protonmail.com')])
# dict_items([('backer_id', 'fb822'), ('cf_id', 65), ('name', 'Fabrizia Beckert'), ('email', 'fbeckert@outlook.com')])
# dict_items([('backer_id', 'hl483'), ('cf_id', 65), ('name', 'Hassie Lortie'), ('email', 'hlortie@gmail.com')])
# dict_items([('backer_id', 'am522'), ('cf_id', 65), ('name', 'Amara Morrow'), ('email', 'amorrow@live.com')])
# dict_items([('backer_id', 'yd385'), ('cf_id', 65), ('name', 'Yann Dudley'), ('email', 'ydudley@gmail.com')])
# dict_items([('backer_id', 'pg994'), ('cf_id', 238), ('name', 'Patrizia Gerhardt'), ('email', 'pgerhardt@gmail.com')])
# dict_items([('backer_id', 'ss878'), ('cf_id', 563), ('name', 'Sherilyn Salle'), ('email', 'ssalle@outlook.com')])
# dict_items([('backer_id', 'jc530'), ('cf_id', 65), ('name', 'Judson Corda'), ('email', 'jcorda@live.com')])
# dict_items([('backer_id', 'uc280'), ('cf_id', 65), ('name', 'Ulrich Casey'), ('email', 'ucasey@yandex.com')])
# dict_items([('backer_id', 'yo890'), ('cf_id', 65), ('name', 'Yasmine Ortega'), ('email', 'yortega@yandex.com')])
# dict_items([('backer_id', 'jl151'), ('cf_id', 1572), ('name', 'Julene Leroux'), ('email', 'jleroux@live.com')])
# dict_items([('backer_id', 'tc958'), ('cf_id', 563), ('name', 'Terresa Conetta'), ('email', 'tconetta@protonmail.com')])
# dict_items([('backer_id', 'bb468'), ('cf_id', 238), ('name', 'Benno Blankenship'), ('email', 'bblankenship@outlook.com')])
# dict_items([('backer_id', 'ek984'), ('cf_id', 65), ('name', 'Elya Kemp'), ('email', 'ekemp@gmail.com')])
# dict_items([('backer_id', 'tr337'), ('cf_id', 563), ('name', 'Tulio Richter'), ('email', 'trichter@protonmail.com')])
# dict_items([('backer_id', 'dc332'), ('cf_id', 65), ('name', 'Damien Catalani'), ('email', 'dcatalani@protonmail.com')])
# dict_items([('backer_id', 'lt266'), ('cf_id', 968), ('name', 'Lambert Taylor'), ('email', 'ltaylor@outlook.com')])
# dict_items([('backer_id', 'jp331'), ('cf_id', 1911), ('name', 'Jesper Preston'), ('email', 'jpreston@outlook.com')])
# dict_items([('backer_id', 'ch149'), ('cf_id', 65), ('name', 'Celso Habich'), ('email', 'chabich@protonmail.com')])
# dict_items([('backer_id', 'ov932'), ('cf_id', 563), ('name', 'Owen Verdier'), ('email', 'overdier@yandex.com')])
# dict_items([('backer_id', 'jg157'), ('cf_id', 65), ('name', 'Jacqueline Glover'), ('email', 'jglover@gmail.com')])
# dict_items([('backer_id', 'lf543'), ('cf_id', 563), ('name', 'Lunette Fitzgerald'), ('email', 'lfitzgerald@protonmail.com')])
# dict_items([('backer_id', 'ew441'), ('cf_id', 65), ('name', 'Enrichetta Wolff'), ('email', 'ewolff@outlook.com')])
# dict_items([('backer_id', 'll550'), ('cf_id', 65), ('name', 'Lera Lacroix'), ('email', 'llacroix@protonmail.com')])
# dict_items([('backer_id', 'yh832'), ('cf_id', 968), ('name', 'Youna Herrera'), ('email', 'yherrera@outlook.com')])
# dict_items([('backer_id', 'ag676'), ('cf_id', 65), ('name', 'Arnoldo Gabler'), ('email', 'agabler@gmail.com')])
# dict_items([('backer_id', 'cm750'), ('cf_id', 563), ('name', 'Carolynn Marois'), ('email', 'cmarois@yahoo.com')])
# dict_items([('backer_id', 'tc578'), ('cf_id', 65), ('name', 'Tamatha Caridi'), ('email', 'tcaridi@gmail.com')])
# dict_items([('backer_id', 'xt124'), ('cf_id', 563), ('name', 'Xaviera Taylor'), ('email', 'xtaylor@yandex.com')])
# dict_items([('backer_id', 'lh881'), ('cf_id', 968), ('name', 'Laetitia Hobbs'), ('email', 'lhobbs@protonmail.com')])
# dict_items([('backer_id', 'bd768'), ('cf_id', 563), ('name', 'Bruno Dreher'), ('email', 'bdreher@yandex.com')])
# dict_items([('backer_id', 'gm909'), ('cf_id', 65), ('name', 'Gidget Martins'), ('email', 'gmartins@gmail.com')])
# dict_items([('backer_id', 'ec360'), ('cf_id', 563), ('name', 'Edda Ciambrone'), ('email', 'eciambrone@live.com')])
# dict_items([('backer_id', 'dg792'), ('cf_id', 65), ('name', 'Donatien Grosz'), ('email', 'dgrosz@yandex.com')])
# dict_items([('backer_id', 'cc155'), ('cf_id', 968), ('name', 'Claribel Collard'), ('email', 'ccollard@gmail.com')])
# dict_items([('backer_id', 'bj789'), ('cf_id', 65), ('name', 'Beate Joseph'), ('email', 'bjoseph@protonmail.com')])
# dict_items([('backer_id', 'ma252'), ('cf_id', 2488), ('name', 'Murray Archambault'), ('email', 'marchambault@outlook.com')])
# dict_items([('backer_id', 'll103'), ('cf_id', 563), ('name', 'Laine Lorino'), ('email', 'llorino@protonmail.com')])
# dict_items([('backer_id', 'nb527'), ('cf_id', 1572), ('name', 'Nicolaus Black'), ('email', 'nblack@gmail.com')])
# dict_items([('backer_id', 'ra872'), ('cf_id', 65), ('name', 'Ricciardo Acevedo'), ('email', 'racevedo@live.com')])
# dict_items([('backer_id', 'ac509'), ('cf_id', 65), ('name', 'Adolfo Corriveau'), ('email', 'acorriveau@yahoo.com')])
# dict_items([('backer_id', 'mh501'), ('cf_id', 65), ('name', 'Marco Hobbs'), ('email', 'mhobbs@outlook.com')])
# dict_items([('backer_id', 'tb312'), ('cf_id', 65), ('name', 'Tamatha Bambach'), ('email', 'tbambach@protonmail.com')])
# dict_items([('backer_id', 'st581'), ('cf_id', 65), ('name', 'Serita Thebault'), ('email', 'sthebault@yandex.com')])
# dict_items([('backer_id', 'gf637'), ('cf_id', 563), ('name', 'Glenn Foerstner'), ('email', 'gfoerstner@yahoo.com')])
# dict_items([('backer_id', 'rc983'), ('cf_id', 1114), ('name', 'Robt Collin'), ('email', 'rcollin@outlook.com')])
# dict_items([('backer_id', 'cz381'), ('cf_id', 65), ('name', 'Corina Zappa'), ('email', 'czappa@outlook.com')])
# dict_items([('backer_id', 'fg535'), ('cf_id', 65), ('name', 'Freeman Gibbs'), ('email', 'fgibbs@outlook.com')])
# [['av166', 968, 'Angelo Vincent', 'avincent@live.com'], ['ha127', 563, 'Hubert Arnold', 'harnold@yandex.com'], ['lg794', 65, 'Loris Goulet', 'lgoulet@yandex.com'], ['tb566', 563, 'Teodora Brunelli', 'tbrunelli@outlook.com'], ['lh506', 563, 'Lexie Hunt', 'lhunt@live.com'], ['lh382', 563, 'Lambert Huber', 'lhuber@live.com'], ['em444', 563, 'Emmy Morin', 'emorin@live.com'], ['at582', 1572, 'Armonda Trani', 'atrani@live.com'], ['id772', 1911, 'Ilana Duke', 'iduke@outlook.com'], ['lw275', 65, 'Leigha Wright', 'lwright@live.com'], ['ub509', 65, 'Uwe Becker', 'ubecker@yahoo.com'], ['ha915', 1572, 'Hawa Audy', 'haudy@gmail.com'], ['bb881', 968, 'Bia Bonura', 'bbonura@yahoo.com'], ['mg332', 65, 'Michel Garner', 'mgarner@protonmail.com'], ['kd700', 1572, 'Karole Dunn', 'kdunn@yahoo.com'], ['as695', 563, 'Arndt Schreiber', 'aschreiber@yahoo.com'], ['iv513', 65, 'Imen Villeneuve', 'ivilleneuve@yahoo.com'], ['ab842', 65, 'Alcina Bonadonna', 'abonadonna@yandex.com'], ['re181', 1114, 'Raelene Espinoza', 'respinoza@outlook.com'], ['kn133', 65, 'Kati Nash', 'knash@protonmail.com'], ['gj893', 65, 'Georg Jager', 'gjager@yahoo.com'], ['vp915', 948, 'Virgilio Paolella', 'vpaolella@gmail.com'], ['ja995', 563, 'Jerrica Avila', 'javila@protonmail.com'], ['ga249', 563, 'Gianni Achterberg', 'gachterberg@live.com'], ['td403', 65, 'Timoteo Dion', 'tdion@gmail.com'], ['tv463', 1572, 'Teodoro Verno', 'tverno@yandex.com'], ['mw606', 65, 'Morris Waller', 'mwaller@protonmail.com'], ['hc648', 65, 'Hans Chen', 'hchen@yandex.com'], ['ta379', 563, 'Trilby Auer', 'tauer@yahoo.com'], ['tj583', 1572, 'Theola Jodoin', 'tjodoin@yandex.com'], ['tc559', 65, 'Tova Capri', 'tcapri@live.com'], ['ww629', 65, 'Wanda Walton', 'wwalton@protonmail.com'], ['jg155', 1572, 'Justine Gill', 'jgill@yahoo.com'], ['jd328', 1911, 'Julee Doyle', 'jdoyle@gmail.com'], ['ld239', 65, 'Lisbeth Deliso', 'ldeliso@gmail.com'], ['cv918', 968, 'Carl Valdez', 'cvaldez@gmail.com'], ['kb145', 563, 'Kelyan Butler', 'kbutler@yahoo.com'], ['dw578', 65, 'Donat Weber', 'dweber@live.com'], ['ad511', 65, 'Alethia Delorme', 'adelorme@outlook.com'], ['db633', 65, 'Darrell Bernardi', 'dbernardi@yandex.com'], ['cr369', 65, 'Carina Reeves', 'creeves@gmail.com'], ['mr978', 65, 'Marvin Ruiz', 'mruiz@outlook.com'], ['md167', 1572, 'Mariabella Duerr', 'mduerr@live.com'], ['jr877', 1572, 'Jeni Ricco', 'jricco@live.com'], ['om753', 65, 'Otto Munoz', 'omunoz@yahoo.com'], ['ng231', 1114, 'Nesrine Gensch', 'ngensch@yandex.com'], ['tl316', 65, 'Tullio Lejeune', 'tlejeune@outlook.com'], ['dl139', 563, 'Dreama Lonardo', 'dlonardo@live.com'], ['mw253', 968, 'Maryrose West', 'mwest@live.com'], ['im424', 65, 'Irina Mays', 'imays@yandex.com'], ['mb131', 968, 'Marcelo Brose', 'mbrose@protonmail.com'], ['nc240', 1572, 'Nestor Coutant', 'ncoutant@gmail.com'], ['ab318', 1572, 'Aloysius Braun', 'abraun@live.com'], ['af301', 65, 'Amos Ferre', 'aferre@gmail.com'], ['bl736', 563, 'Brigitte Lynch', 'blynch@outlook.com'], ['ar957', 65, 'Alegra Ramsey', 'aramsey@yahoo.com'], ['cb474', 968, 'Conchita Beitel', 'cbeitel@gmail.com'], ['dv246', 1572, 'Donnie Vernet', 'dvernet@protonmail.com'], ['cj111', 563, 'Cyril Jones', 'cjones@protonmail.com'], ['lh765', 563, 'Lucinda Hays', 'lhays@outlook.com'], ['wh697', 65, 'Walter Hermann', 'whermann@outlook.com'], ['eb714', 65, 'Emil Blanc', 'eblanc@protonmail.com'], ['ec356', 1572, 'Eldwin Cesare', 'ecesare@protonmail.com'], ['yh129', 65, 'Yusuf Hudson', 'yhudson@protonmail.com'], ['as494', 65, 'Arrigo Salazar', 'asalazar@gmail.com'], ['lb146', 563, 'Levi Beck', 'lbeck@gmail.com'], ['cc470', 563, 'Celinda Caillet', 'ccaillet@yandex.com'], ['mm239', 563, 'Marcus Medici', 'mmedici@gmail.com'], ['dg360', 65, 'Daysi Gamble', 'dgamble@yahoo.com'], ['rh399', 1572, 'Rory Hildebrand', 'rhildebrand@yahoo.com'], ['hr430', 65, 'Heini Raffin', 'hraffin@yahoo.com'], ['ar829', 65, 'Anna Randall', 'arandall@outlook.com'], ['sw301', 65, 'Sharmaine Weber', 'sweber@yahoo.com'], ['rr355', 65, 'Ranee Renault', 'rrenault ...

# %%
# Create a backers_df DataFrame with the following columns: 'backer_id','cf_id', 'name', and 'email' 
# using the list of values lists. 
backer_info_clean_df = pd.DataFrame(backer_dict_values, columns = ['backer_id','cf_id','name','email'])
backer_info_clean_df.head()
# Out:
#   backer_id  cf_id              name                  email
# 0     av166    968    Angelo Vincent      avincent@live.com
# 1     ha127    563     Hubert Arnold     harnold@yandex.com
# 2     lg794     65      Loris Goulet     lgoulet@yandex.com
# 3     tb566    563  Teodora Brunelli  tbrunelli@outlook.com
# 4     lh506    563        Lexie Hunt         lhunt@live.com

# %%
# Export the DataFrame as a CSV file using encoding='utf8'.
backer_info_clean_df.to_csv("back_info_clean.csv", index=False, encoding='utf8')

# %% [markdown]
# ## Deliverable 1: Extract
# ----
# ### Option 2: Use regex
#
# 1. Import the `backer_info.csv` file into a DataFrame.
# 2. Extract the "backer_id", "cf_id", "name", and "email using regular expressions."
# 3. Create a new DataFrame with the retrieved data.
# 4. Export the DataFrame as `backers_data.csv`.

# %%
# Get the backers_info from the crowdfunding_info sheet. 
pd.set_option('max_colwidth', 400)
backer_info_df = pd.read_csv('backer_info.csv')
backer_info_df.head()
# Out:
#                                                                                           backer_info
# 0        {"backer_id": "av166", "cf_id": 968, "name": "Angelo Vincent", "email": "avincent@live.com"}
# 1        {"backer_id": "ha127", "cf_id": 563, "name": "Hubert Arnold", "email": "harnold@yandex.com"}
# 2          {"backer_id": "lg794", "cf_id": 65, "name": "Loris Goulet", "email": "lgoulet@yandex.com"}
# 3  {"backer_id": "tb566", "cf_id": 563, "name": "Teodora Brunelli", "email": "tbrunelli@outlook.com"}
# 4               {"backer_id": "lh506", "cf_id": 563, "name": "Lexie Hunt", "email": "lhunt@live.com"}

# %%
# Extract the alpha-numeric "backer_id" from the backer_info column using a regex expression 
# and add it as a new column called "backer_id".
backer_info_df['backer_id']=backer_info_df['backer_info'].str.extract(r'([a-z]{2}\d{3})')
backer_info_df['backer_id']
# Out:
# 0       av166
# 1       ha127
# 2       lg794
# 3       tb566
# 4       lh506
#         ...
# 8170    st581
# 8171    gf637
# 8172    rc983
# 8173    cz381
# 8174    fg535
# Name: backer_id, Length: 8175, dtype: object

# %%
# Extract the two to four-digit "cf_id" number from the backer_info column. 
# and add it as a new column called "cf_id".
backer_info_df['cf_id'] = backer_info_df['backer_info'].str.extract(r'(\d{2,4})')
backer_info_df['cf_id']
# Out:
# 0       166
# 1       127
# 2       794
# 3       566
# 4       506
#        ...
# 8170    581
# 8171    637
# 8172    983
# 8173    381
# 8174    535
# Name: cf_id, Length: 8175, dtype: object

# %%
# Extract the name from the backer_info column and add it as a new column called "name".
backer_info_df['name'] = backer_info_df['backer_info'].str.extract(r'([^"name][A-Za-z]+\s[A-Za-z]+)')
backer_info_df['name']
# Out:
# 0         Angelo Vincent
# 1          Hubert Arnold
# 2           Loris Goulet
# 3       Teodora Brunelli
# 4             Lexie Hunt
#               ...
# 8170     Serita Thebault
# 8171     Glenn Foerstner
# 8172         Robt Collin
# 8173        Corina Zappa
# 8174       Freeman Gibbs
# Name: name, Length: 8175, dtype: object

# %%
# Extract the email from the backer_info column and add it as a new column called "email".
backer_info_df['email'] = backer_info_df['backer_info'].str.extract(r'([^"email][a-z]+@[a-z]+.[a-z]+)')
backer_info_df['email']
# Out:
# 0            vincent@live.com
# 1          harnold@yandex.com
# 2           goulet@yandex.com
# 3       tbrunelli@outlook.com
# 4               hunt@live.com
#                 ...
# 8170     sthebault@yandex.com
# 8171     gfoerstner@yahoo.com
# 8172      rcollin@outlook.com
# 8173       czappa@outlook.com
# 8174       fgibbs@outlook.com
# Name: email, Length: 8175, dtype: object

# %%
# Create a new DataFrame with the appropriate columns.
data = {'backer_id': backer_info_df['backer_id'], 'cf_id': backer_info_df['cf_id'],'name': backer_info_df['name'], 'email': backer_info_df['email']}
backer_info_regex_df = pd.DataFrame(data=data)
backer_info_regex_df.head()
# Out:
#   backer_id cf_id              name                  email
# 0     av166   166    Angelo Vincent       vincent@live.com
# 1     ha127   127     Hubert Arnold     harnold@yandex.com
# 2     lg794   794      Loris Goulet      goulet@yandex.com
# 3     tb566   566  Teodora Brunelli  tbrunelli@outlook.com
# 4     lh506   506        Lexie Hunt          hunt@live.com

# %%
# Export the DataFrame as a CSV file using encoding='utf8'.
backer_info_regex_df.to_csv("back_info_regex_clean.csv", index=False, encoding='utf8')

# %% [markdown]
# ## Deliverable 2: Transform and Clean Data
# ----
# 1. Check the data types of the columns and convert the "cf_id" column to an integer, if necessary.
# 2. Split the name in the "name" column into first and last names, and add them to "first_name" and "last_name" columns in the DataFrame.
# 3. Drop the "name" column in the DataFrame.
# 4. Place the columns in the following order; "backer_id", "cf_id", "first_name", "last_name" and "email".

# %%
# Check data types.
backer_info_clean_df.dtypes
# Out:
# backer_id    object
# cf_id         int64
# name         object
# email        object
# dtype: object

# %%
# Convert cf_id to an integer if necessary.

# %%
# Split the "name" column into "first_name" and "last_name" columns.
backer_info_clean_df[['first_name', 'last_name']] = backer_info_clean_df['name'].str.split(" ", n=1, expand=True)
backer_info_clean_df.head()
# Out:
#   backer_id  cf_id              name                  email first_name  \
# 0     av166    968    Angelo Vincent      avincent@live.com     Angelo
# 1     ha127    563     Hubert Arnold     harnold@yandex.com     Hubert
# 2     lg794     65      Loris Goulet     lgoulet@yandex.com      Loris
# 3     tb566    563  Teodora Brunelli  tbrunelli@outlook.com    Teodora
# 4     lh506    563        Lexie Hunt         lhunt@live.com      Lexie
#
#   last_name
# 0   Vincent
# 1    Arnold
# 2    Goulet
# 3  Brunelli
# 4      Hunt

# %%
#  Drop the name column
backer_info_clean_df = backer_info_clean_df.drop(['name'], axis=1)
backer_info_clean_df.head()
# Reorder the columns
backer_info_clean_df = backer_info_clean_df[['backer_id','cf_id','first_name','last_name','email']]
backer_info_clean_df
# Out:
#      backer_id  cf_id first_name  last_name                  email
# 0        av166    968     Angelo    Vincent      avincent@live.com
# 1        ha127    563     Hubert     Arnold     harnold@yandex.com
# 2        lg794     65      Loris     Goulet     lgoulet@yandex.com
# 3        tb566    563    Teodora   Brunelli  tbrunelli@outlook.com
# 4        lh506    563      Lexie       Hunt         lhunt@live.com
# ...        ...    ...        ...        ...                    ...
# 8170     st581     65     Serita   Thebault   sthebault@yandex.com
# 8171     gf637    563      Glenn  Foerstner   gfoerstner@yahoo.com
# 8172     rc983   1114       Robt     Collin    rcollin@outlook.com
# 8173     cz381     65     Corina      Zappa     czappa@outlook.com
# 8174     fg535     65    Freeman      Gibbs     fgibbs@outlook.com
#
# [8175 rows x 5 columns]

# %%
# Export the DataFrame as a CSV file using encoding='utf8'.
backer_info_clean_df.to_csv('backers.csv', index=False,encoding='utf8')
# Out:
# backer_id     object
# cf_id          int64
# first_name    object
# last_name     object
# email         object
# dtype: object
